# %% [markdown]
# # Importy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import networkx as nx

# %% [markdown]
# # Do wizualizacji

# %%
def bias_to_color(bias, vmin, vmax):
    """Funkcja pomocniczna do liczenia koloru node"""

    if vmin < 0 and vmax > 0:
        # Przypadek 1: mamy biasy ujemne i dodatnie, wówczas używamy red yellow green color mapy
        norm = mcolors.TwoSlopeNorm(vmin=vmin, vcenter=0, vmax=vmax)
        cmap = plt.get_cmap("RdYlGn") 
    elif vmin >= 0:
        # Przypadek 2: Wszystkie biasy >= 0, wówczas używamy yellow green color mapy
        norm = mcolors.Normalize(vmin=vmin, vmax=vmax)
        cmap = plt.get_cmap("YlGn")
    else:
        # Przypadek 3: Wszystkie biasy <= 0, wówczas używamy yellow orange red mapy (reversed, bo jest od yellow do red, a chcemy, żeby vmax był yellow dla ujemnych)
        norm = mcolors.Normalize(vmin=vmin, vmax=vmax)
        cmap = plt.get_cmap("YlOrRd_r")

    return cmap(norm(bias))

def draw_network_networkx(mlp):
    """Wizualizuje stan wag i biasów w sieci:
        - kolor neuronu zależy od wartości biasu (w danej wartwie)
        - kolor krawędzi zależy od znaku odpowiadającej wagi
        - grubość krawędzi zależy od wartości odpowiadającej wagi (tylko dana warstwa)
    """
    G = nx.DiGraph()

    # Zczytaj ilość neuronów
    layers_sizes = []
    input_size = mlp.layers[0].weights.shape[0]
    layers_sizes.append(input_size)
    for layer in mlp.layers:
        layers_sizes.append(layer.weights.shape[1])
    n_layers = len(layers_sizes)

    # Ustal pozycje
    pos = {}
    node_colors = {}
    h_spacing = 2.0  # Odległość horyzontalna między warstwami
    v_spacing = 1.5  # Odległość wertykalna między neuronami tej samej warstwy

    # Ustalamy pozycje i color neuronów
    for i, n_neurons in enumerate(layers_sizes): # dla i-tej warstwy
        x = i * h_spacing
        # Neurony oddzielamy równomiernie w warstwie
        if n_neurons > 1:
            y_positions = np.linspace(0, (n_neurons - 1) * v_spacing, n_neurons)
            y_positions = y_positions - np.max(y_positions) / 2
        else:
            y_positions = np.array([0])
        
        for j, y in enumerate(y_positions): # dla j-tego neuronu w i-tej warstwie
            node_id = (i, j)
            pos[node_id] = (x, y) # ustalamy pozycje neuronu
            if i == 0:
                # Dla input layer ustawiamy kolor neutralny
                node_colors[node_id] = 'lightblue'
            else: # Dla innej niż input layer
                bias = mlp.layers[i-1].biases[j]
                biases_layer = mlp.layers[i-1].biases
                # Normalizujemy kolor funkcją pomociczą
                if len(biases_layer) > 1: # Jeśli mamy > jeden neuron w wartstwie
                    vmin, vmax = np.min(biases_layer), np.max(biases_layer)
                    node_colors[node_id] = bias_to_color(bias, vmin, vmax)
                else: # Jeśli jest jeden nauron
                    node_colors[node_id] = "red" if bias < 0 else "green"
                    
            G.add_node(node_id)

    # Ustalamy grubość połączeń między neuronami na podstawie wag
    for i, layer in enumerate(mlp.layers): # DLa i-tej wastwy
        weights = layer.weights  # połączenie i-tej oraz (i+1)-tej warstwy
        max_weight = np.max(np.abs(weights))
        # Unkamy dzielenia przez 0
        if max_weight == 0:
            max_weight = 1
        for j in range(weights.shape[0]): # DLa j-tego neuronu z i-tej warstwy
            for k in range(weights.shape[1]): # Dla k-tego neurony z (i+1)-tej warstwy
                source = (i, j) # Od j tego neuronu z i-tej warstwy
                target = (i+1, k) # Do k-tego z i+1
                weight = weights[j, k]
                # Skalujemy grubość połączenia (w danej warstwie)
                lw = 0.5 + 5 * (abs(weight) / max_weight)
                color = "red" if weight < 0 else "green"
                G.add_edge(source, target, weight=weight, width=lw, color = color)

    # Rysujemy graf
    fig, ax = plt.subplots(figsize=(12, 8))
    # Rysujemy neurony z kolorami
    node_color_list = [node_colors[node] for node in G.nodes()]
    nx.draw_networkx_nodes(G, pos, node_color=node_color_list, node_size=800, ax=ax)
    
    # Rysujemy połączenia z grubością i kolorami
    edge_widths = [d['width'] for (_, _, d) in G.edges(data=True)]
    edge_colors = [d['color'] for (_, _, d) in G.edges(data=True)]
    nx.draw_networkx_edges(G, pos, ax=ax, width=edge_widths, edge_color=edge_colors)
    
    # Labelujemy neurony za pomocą indexu w warstwie
    labels = {node: f"{node[1]}" for node in G.nodes()}
    nx.draw_networkx_labels(G, pos, labels, font_size=10, ax=ax)

    ax.set_title("Neural Net Visualization")
    ax.axis('off')
    plt.show()

def show_loss(epoch_arr, loss_arr):
    plt.figure(figsize = (12, 8))
    plt.plot(epoch_arr, loss_arr)
    plt.title("Loss vs epochs")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.show()

def eval_2d(network, x, y):
    y_pred = network.predict(x)
    plt.scatter(x, y, s = 1, label = "True")
    plt.scatter(x, y_pred, s=1, label = "Predicted")
    plt.title(f"How fun is fitting desired y")
    plt.legend()
    plt.show()

# %% [markdown]
# # Definicja sieci

# %% [markdown]
# Zmiany:
# - dodanie nowych funkcji aktywacji (ciągle pamiętając o tym, że wewnętrznie zakładyamy, że używamy dla szybszego liczenia outputu funkcji w punkcie do liczenia jej pochodnej w tym samym punkcie) (uniemożliwia to mieszanie funkcji aktywacji w warstwach)
# - dodanie inicializacji wag He

# %%
class Optimizer:
    def update(self, layer, dW, db):
        raise NotImplementedError("This method should be overridden")

class SGD(Optimizer):
    def __init__(self, lr=0.05):
        self.lr = lr

    def update(self, layer, dW, db):
        layer.weights -= self.lr * dW
        layer.biases  -= self.lr * db

class Momentum(Optimizer):
    def __init__(self, lr=0.05, lamb=0.9):
        self.lr = lr
        self.lamb = lamb
        self.momentum = {}

    def update(self, layer, dW, db):
        # Inicjujemy momentum
        if layer not in self.momentum:
            self.momentum[layer] = {'dW': np.zeros_like(dW), 'db': np.zeros_like(db)}

        ## Version 1
        # # Update sredniej
        # self.momentum[layer]['dW'] = self.lamb * self.momentum[layer]['dW'] - self.lr * dW
        # self.momentum[layer]['db'] = self.lamb * self.momentum[layer]['db'] - self.lr * db
        # # Update parametrow
        # layer.weights += self.momentum[layer]['dW']
        # layer.biases  += self.momentum[layer]['db']
        
        ## Version 2
        # Update momentum
        self.momentum[layer]['dW'] = self.lamb * self.momentum[layer]['dW'] - dW
        self.momentum[layer]['db'] = self.lamb * self.momentum[layer]['db'] - db
        
        # Update parameters using the momentum
        layer.weights += self.lr * self.momentum[layer]['dW']
        layer.biases  += self.lr * self.momentum[layer]['db']

class RMSProp(Optimizer):
    def __init__(self, lr=0.05, beta = 0.9):
        self.lr = lr
        self.beta = beta
        self.mean_sq_grad = {}
    
    def update(self, layer, dW, db):
        # Inicjujemy
        if layer not in self.mean_sq_grad:
            self.mean_sq_grad[layer] = {'dW': np.zeros_like(dW), 'db': np.zeros_like(db)}
        # Update sredniej
        self.mean_sq_grad[layer]['dW'] = self.beta * self.mean_sq_grad[layer]['dW'] + (1 - self.beta) * dW ** 2
        self.mean_sq_grad[layer]['db'] = self.beta * self.mean_sq_grad[layer]['db'] + (1 - self.beta) * db ** 2

        # Update parametrow
        layer.weights -= self.lr * dW / np.sqrt(self.mean_sq_grad[layer]['dW'] + np.finfo(float).eps)
        layer.biases  -= self.lr * db / np.sqrt(self.mean_sq_grad[layer]['db'] + np.finfo(float).eps)

class Adam(Optimizer):
    def __init__(self, lr=0.01, beta1 = 0.9, beta2 = 0.999, epsilon = np.finfo(float).eps):
        self.lr = lr
        self.beta1 = beta1
        self.beta2 = beta2
        self.m = {}
        self.v = {}
        self.t = {}
        self.epsilon = epsilon
        
    def update(self, layer, dW, db):
        # Inicjujemy
        if layer not in self.m:
            self.m[layer] = {'dW': np.zeros_like(dW), 'db': np.zeros_like(db)}
            self.v[layer] = {'dW': np.zeros_like(dW), 'db': np.zeros_like(db)}
            self.t[layer] = 0

        # Set t
        self.t[layer] += 1
        
        # Update weights
        self.m[layer]["dW"] = self.beta1 * self.m[layer]["dW"] + (1 - self.beta1) * dW
        self.v[layer]["dW"] = self.beta2 * self.v[layer]["dW"] + (1 - self.beta2) * dW**2
        m_hat = self.m[layer]["dW"] / (1 - self.beta1**self.t[layer])
        v_hat = self.v[layer]["dW"] / (1 - self.beta2**self.t[layer])
        layer.weights -= self.lr * m_hat / (np.sqrt(v_hat) + self.epsilon)

        # Update bias
        self.m[layer]["db"] = self.beta1 * self.m[layer]["db"] + (1 - self.beta1) * db
        self.v[layer]["db"] = self.beta2 * self.v[layer]["db"] + (1 - self.beta2) * db**2
        m_hat = self.m[layer]["db"] / (1 - self.beta1**self.t[layer])
        v_hat = self.v[layer]["db"] / (1 - self.beta2**self.t[layer])
        layer.biases -= self.lr * m_hat / (np.sqrt(v_hat) + self.epsilon)

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))
def sigmoid_deriv(output):
    # Zakłada, że wejściem jest "a", a nie "z" (czyli, że jest to już po zastosowaniu sigmoid(a))
    return output * (1 - output)
def linear(x):
    return x
def linear_deriv(x):
    return 1.0
def softmax(z):
    d = -np.max(z, axis=1, keepdims=True)
    return np.exp(z + d) / np.sum(np.exp(z + d), axis=1, keepdims=True)
    
def mse(y_true, y_pred):
    return np.mean((y_true - y_pred)**2)
def cross_entropy(y_true, y_pred):
    epsilon = 1e-12
    return -np.mean(np.sum(y_true*np.log(y_pred + epsilon), axis=1))
def cross_entropy_from_logits(y_true, logits):
    y_pred = softmax(logits)    
    return cross_entropy(y_true, y_pred)
def one_hot(x):
    result = np.int64(np.zeros((x.size, x.max() + 1)))
    result[np.arange(x.size), x] = 1
    return result
def one_hot_from_probabilities(y_pred):
    return one_hot(y_pred.argmax(axis=1))
def from_one_hot_to_label(x):
    return x.argmax(axis=1)
def f1_score(y_true, y_pred): # Zakładamy, że są to predykcje trybie "labelled", czyli wektor [0, 1, 2, 1, ..]
    classes = np.unique(np.concatenate((y_true, y_pred)))
    f1_arr = []
    for cls in classes:
        tp = np.sum((y_true == cls) & (y_pred == cls))
        fp = np.sum((y_true != cls) & (y_pred == cls))
        fn = np.sum((y_true == cls) & (y_pred != cls))
        if tp == 0:
            f1 = 0.0
        else:
            precision = tp / (tp + fp)
            recall = tp / (tp + fn)
            f1 = 2 * precision * recall / (precision + recall)
        f1_arr.append(f1)
    return np.mean(f1_arr)

# Nowe funkcje aktywacji
def tanh(x):
    return np.tanh(x)

def tanh_deriv(output):
    # Zakłada, że wejściem jest "a", a nie "z" (czyli, że jest to już po zastosowaniu tanh(a))
    return 1 - np.power(output, 2)

def relu(x):
    return np.maximum(0, x)

def relu_deriv(a_out):
    # Zakłada, że wejściem jest "a", a nie "z" (czyli, że jest to już po zastosowaniu relu(a))
    return np.where(a_out > 0, 1.0, 0.0)

def leaky_relu(x, alpha=0.01):
    return np.where(x > 0, x, alpha * x)

def leaky_relu_deriv(a_out, alpha=0.01):
    # Zakłada, że wejściem jest "a", a nie "z" (czyli, że jest to już po zastosowaniu leaky_relu(a))
    return np.where(a_out > 0, 1.0, alpha)
    

class Layer: # Warstwa sieci
    def __init__(self, input_size, output_size, act_fun, act_derivative, init_type = 'random'):
        if init_type == "random":
            self.weights = np.random.random((input_size, output_size))
            self.biases = np.random.random(output_size)
        elif init_type == "xavier":
            limit = np.sqrt(2 / (input_size + output_size))
            self.weights = np.random.randn(input_size, output_size) * limit
            self.biases = np.zeros(output_size)
        elif init_type == "he":
            self.weights = np.random.randn(input_size, output_size) * np.sqrt(2 / input_size)
            self.biases = np.zeros(output_size)
        self.act_fun = act_fun
        self.act_derivative = act_derivative
        self.a_in = None
        self.z = None
        self.a_out = None

    def forward(self, x):
        self.a_in = x
        z = np.dot(x, self.weights) + self.biases
        self.z = z
        z = self.act_fun(z)
        self.a_out = z
        return z

    def backward(self, dA):
        # dC / dz
        dZ = self.act_derivative(self.a_out) * dA # zakładamy, że używamy act_derivative na "a", a nie na "z". W przypadku ostatniej warstwy nie ma to znaczenia, o ile zakładamy, że wyjście jest funkcją liniową, a zatem ma stałą pochodną
        # Zmiana na wagach (L)
        dW = np.dot(self.a_in.T, dZ)
        # Zmiana na bias (L)
        db = np.sum(dZ, axis=0)
        # Zmiana dA (L-1)
        dA_in = np.dot(dZ, self.weights.T)
        return dA_in, dW, db
    
    def show_params(self):
        print("Weights")
        print(self.weights)
        print("Biases")
        print(self.biases)

class MLP: # Cała sieć
    def __init__(self, neural_arr, act_fun, act_derivative, out_fun, out_derivative, init_type = "random"):
        self.layers = []
        for i in range(len(neural_arr) - 2):
            self.layers.append(Layer(neural_arr[i], neural_arr[i+1], act_fun, act_derivative, init_type))
        self.layers.append(Layer(neural_arr[-2], neural_arr[-1], out_fun, out_derivative, init_type))

        # Do standaryzacji potem
        self.input_mean = None
        self.input_std = None
        self.output_mean = None
        self.output_std = None

    def standarize_input(self, x):
        return (x - self.input_mean) / self.input_std
    def standarize_output(self, y):
        return (y - self.output_mean) / self.output_std
    def destandarize_output(self, y_std):
        return y_std * self.output_std + self.output_mean

    def forward(self, x):
        z = x.copy()
        for i in range(len(self.layers)):
            z = self.layers[i].forward(z)
        return z
        
    def predict(self, x):
        x_std = self.standarize_input(x)
        y_std = self.forward(x_std)
        return self.destandarize_output(y_std)

    def backward(self, dA, optimizer):
        for layer in reversed(self.layers):
            dA, dW, db = layer.backward(dA)
            optimizer.update(layer, dW, db)

    def train(self, x, y, epochs = 100, loss_fun = mse, optimizer = None, batch_size = None):
        """Batch Gradient Descent by default"""
        # Zapisuje średnie i odchylenia inputu i outputu
        self.input_mean = np.mean(x, axis=0)
        self.input_std = np.std(x, axis=0)
        self.output_mean = np.mean(y, axis=0)
        self.output_std = np.std(y, axis=0)

        # standaryzuje x i y zanim zaczne uczyc
        x_std = self.standarize_input(x)
        y_std = self.standarize_output(y)

        if batch_size == None: # Zapewnia, że jest to batch gradient descent by default
            batch_size = y.shape[0]
        optimizer = optimizer if optimizer is not None else SGD(lr=0.05) # Zapewnia, że istnieje optimizer
        
        # Trenujemy
        for epoch in range(epochs):
            loss = 0

            if batch_size != 1:
                # tworze batche
                order = np.arange(y.shape[0])
                np.random.shuffle(order)
                batches = np.array_split(order, len(order) // batch_size + (len(order) % batch_size != 0) )
            else: # Znacznie polepsza czas gdy chcemy brac jedna probke na raz (sgd)
                batches = np.arange(y.shape[0]).reshape(-1, 1)
            
            for batch in batches:
                x_tmp = x_std[batch, :]
                y_tmp = y_std[batch, :]
                # Forward
                y_pred_std = self.forward(x_tmp)
                loss += loss_fun(y_tmp, y_pred_std)
                # Backward
                # Trzeba podzielić jeszcze przez wielkość próby, bo gradient "na raz" chcę się za dużo poprawić / batch_size
                dA = (y_pred_std - y_tmp) / batch_size
                self.backward(dA, optimizer)

            loss = loss / len(batches)
            if epoch % int(epochs / 20) == 0:
                print(f"Epoch: {epoch+1}, Loss (standarized): {loss}")
        
        print(f"Final epoch: {epoch+1}, Final loss (standarized): {loss}")

    def train_to_visualize(self, x, y, epochs = 100, loss_fun=mse, optimizer = None, batch_size = None):
        """Batch Gradient Descent by default"""
        # Zapisuje średnie i odchylenia inputu i outputu
        self.input_mean = np.mean(x, axis=0)
        self.input_std = np.std(x, axis=0)
        self.output_mean = np.mean(y, axis=0)
        self.output_std = np.std(y, axis=0)

        # standaryzuje x i y zanim zaczne uczyc
        x_std = self.standarize_input(x)
        y_std = self.standarize_output(y)

        if batch_size == None: # Zapewnia, że jest to batch gradient descent by default
            batch_size = y.shape[0]
        optimizer = optimizer if optimizer is not None else SGD(lr=0.05) # Zapewnia, że istnieje optimizer
        
        # Trenujemy
        loss_history = np.zeros(epochs)
        for epoch in range(epochs):
            loss = 0

            if batch_size != 1:
                # tworze batche
                order = np.arange(y.shape[0])
                np.random.shuffle(order)
                batches = np.array_split(order, len(order) // batch_size + (len(order) % batch_size != 0) )
            else: # Znacznie polepsza czas gdy chcemy brac jedna probke na raz (sgd)
                batches = np.arange(y.shape[0]).reshape(-1, 1)
            
            for batch in batches:
                x_tmp = x_std[batch]
                y_tmp = y_std[batch]
                # Forward
                y_pred_std = self.forward(x_tmp)
                loss += loss_fun(y_tmp, y_pred_std)
                # Backward
                # Trzeba podzielić jeszcze przez wielkość próby, bo gradient "na raz" chcę się za dużo poprawić / batch_size
                dA = (y_pred_std - y_tmp) / batch_size
                self.backward(dA, optimizer)

            loss = loss / len(batches)
            loss_history[epoch] = loss
            if epoch % int(epochs / 20) == 0:
                print(f"Epoch: {epoch+1}, Loss (standarized): {loss}")
        
        print(f"Final epoch: {epoch+1}, Final loss (standarized): {loss}")
        
        return loss_history

    def train_classify(self, x, y, epochs = 100, loss_fun = cross_entropy, optimizer = None, batch_size = None):
        # Zapisuje średnie i odchylenia inputu i outputu
        self.input_mean = np.mean(x, axis=0)
        self.input_std = np.std(x, axis=0)
        self.output_mean = 0
        self.output_std = 1

        # standaryzuje x zanim zaczne uczyc
        x_std = self.standarize_input(x)
        y_std = y

        if batch_size == None: # Zapewnia, że jest to batch gradient descent by default
            batch_size = y.shape[0]
        optimizer = optimizer if optimizer is not None else SGD(lr=0.05) # Zapewnia, że istnieje optimizer
        
        # Trenujemy
        loss_history = np.zeros(epochs)
        for epoch in range(epochs):
            loss = 0

            if batch_size != 1:
                # tworze batche
                order = np.arange(y.shape[0])
                np.random.shuffle(order)
                batches = np.array_split(order, len(order) // batch_size + (len(order) % batch_size != 0) )
            else: # Znacznie polepsza czas gdy chcemy brac jedna probke na raz (sgd)
                batches = np.arange(y.shape[0]).reshape(-1, 1)
            
            for batch in batches:
                x_tmp = x_std[batch, :]
                y_tmp = y_std[batch, :]
                # Forward
                y_pred_std = self.forward(x_tmp)
                loss += loss_fun(y_tmp, y_pred_std)
                # Backward
                # Trzeba podzielić jeszcze przez wielkość próby, bo gradient "na raz" chcę się za dużo poprawić / batch_size
                dA = (y_pred_std - y_tmp) / batch_size
                self.backward(dA, optimizer)

            loss = loss / len(batches)
            loss_history[epoch] = loss
            if epoch % int(epochs / 20) == 0:
                print(f"Epoch: {epoch+1}, Loss (standarized): {loss}")
        
        print(f"Final epoch: {epoch+1}, Final loss (standarized): {loss}")
        return loss_history

    def show_params(self):
        for i in range(len(self.layers)):
            print("Layer: ", i)
            self.layers[i].show_params()
            print("")

# %% [markdown]
# # Content

# %% [markdown]
# ## Dane multimodal - large (wstępne testy)

# %% [markdown]
# ### Pobranie

# %%
# Pobieramy dane
data_train = pd.read_csv("../Data/regression/multimodal-large-training.csv").to_numpy()
x_train = data_train[:, 0].reshape(-1, 1)
y_train = data_train[:, 1].reshape(-1, 1)

data_test = pd.read_csv("../Data/regression/multimodal-large-test.csv").to_numpy()
x_test = data_test[:, 0].reshape(-1, 1)
y_test = data_test[:, 1].reshape(-1, 1)

# %%
plt.scatter(x_train, y_train, s = 1, label = "train data")
plt.scatter(x_test, y_test, s = 1, label = "test_data")
plt.legend()
plt.show()

# %% [markdown]
# ### Testy (liniowej jako aktywacji nie biorę pod uwagę nawet, bo to bez sensu)

# %%
np.random.seed(123)
archs = [[1, 5, 1], [1, 5, 5, 1], [1, 5, 5, 5, 1], [1, 20, 20, 1]]
funs = [sigmoid, tanh, relu, leaky_relu]
fun_derivs = [sigmoid_deriv, tanh_deriv, relu_deriv, leaky_relu_deriv]
initialization = ["xavier", "xavier", "he", "he"]
results = { "Arch": [],
            "Fun": [],
            "Test_loss": [],
            "Train_results": []}

for arch in archs:
    for i in range(len(funs)):
        net = MLP(arch, act_fun=funs[i], act_derivative=fun_derivs[i], out_fun=linear, out_derivative=linear_deriv, init_type=initialization[i])
        curr_result = net.train_to_visualize(x = x_train, y = y_train, epochs = 1000, optimizer=Adam(), batch_size=512)
        y_pred = net.predict(x_test)
        test_loss = mse(y_pred, y_test)
        results["Arch"].append(arch)
        results["Fun"].append(funs[i])
        results["Test_loss"].append(test_loss)
        results["Train_results"].append(curr_result)
# Out:
# Epoch: 1, Loss (standarized): 1.3933608759143525
# Epoch: 51, Loss (standarized): 0.4075625393066155
# Epoch: 101, Loss (standarized): 0.26329033032002414
# Epoch: 151, Loss (standarized): 0.11865893086917637
# Epoch: 201, Loss (standarized): 0.08914323468042998
# Epoch: 251, Loss (standarized): 0.08155392618114757
# Epoch: 301, Loss (standarized): 0.07944037123090639
# Epoch: 351, Loss (standarized): 0.0786467430133226
# Epoch: 401, Loss (standarized): 0.07811418726546415
# Epoch: 451, Loss (standarized): 0.07774958466019574
# Epoch: 501, Loss (standarized): 0.077684029234532
# Epoch: 551, Loss (standarized): 0.07761966321046845
# Epoch: 601, Loss (standarized): 0.07739350379693834
# Epoch: 651, Loss (standarized): 0.07729522508966995
# Epoch: 701, Loss (standarized): 0.07735620912360817
# Epoch: 751, Loss (standarized): 0.07702907952091878
# Epoch: 801, Loss (standarized): 0.07716150320934004
# Epoch: 851, Loss (standarized): 0.07693520927431385
# Epoch: 901, Loss (standarized): 0.0768926824555184
# Epoch: 951, Loss (standarized): 0.07659742095237163
# Final epoch: 1000, Final loss (standarized): 0.07661218873660132
# Epoch: 1, Loss (standarized): 1.0173107320917931
# Epoch: 51, Loss (standarized): 0.2960677180553096
# Epoch: 101, Loss (standarized): 0.08635009918585555
# Epoch: 151, Loss (standarized): 0.0804671561350422
# Epoch: 201, Loss (standarized): 0.07893723437577344
# Epoch: 251, Loss (standarized): 0.07770894345250172
# Epoch: 301, Loss (standarized): 0.07745678292394773
# Epoch: 351, Loss (standarized): 0.0768882909356103
# Epoch: 401, Loss (standarized): 0.07634504567534037
# Epoch: 451, Loss (standarized): 0.07533420869701195
# Epoch: 501, Loss (standarized): 0.07418516025488871
# Epoch: 551, Loss (standarized): 0.07344967688652801
# Epoch: 601, Loss (standarized): 0.07257199854323336
# Epoch: 651, Loss (standarized): 0.07220000637980373
# Epoch: 701, Loss (standarized): 0.07178571557450568
# Epoch: 751, Loss (standarized): 0.07122365421914276
# Epoch: 801, Loss (standarized): 0.07116068489694453
# Epoch: 851, Loss (standarized): 0.0700620276127952
# Epoch: 901, Loss (standarized): 0.0694853067796465
# Epoch: 951, Loss (standarized): 0.06926078966542956
# Final epoch: 1000, Final loss (standarized): 0.06922105291523518
# Epoch: 1, Loss (standarized): 0.781493217901631
# Epoch: 51, Loss (standarized): 0.34115699239125313
# Epoch: 101, Loss (standarized): 0.3225328314650642
# Epoch: 151, Loss (standarized): 0.31570600485562184
# Epoch: 201, Loss (standarized): 0.31397049963106405
# Epoch: 251, Loss (standarized): 0.31389271402971297
# Epoch: 301, Loss (standarized): 0.31208527300744404
# Epoch: 351, Loss (standarized): 0.31927402141073646
# Epoch: 401, Loss (standarized): 0.3114694002313763
# Epoch: 451, Loss (standarized): 0.3140121697334412
# Epoch: 501, Loss (standarized): 0.313720389592393
# Epoch: 551, Loss (standarized): 0.31067467605939736
# Epoch: 601, Loss (standarized): 0.3115885240872077
# Epoch: 651, Loss (standarized): 0.3162607104418174
# Epoch: 701, Loss (standarized): 0.3144982201031926
# Epoch: 751, Loss (standarized): 0.31264220084063654
# Epoch: 801, Loss (standarized): 0.3121788244929876
# Epoch: 851, Loss (standarized): 0.3110792384785924
# Epoch: 901, Loss (standarized): 0.3150784223018567
# Epoch: 951, Loss (standarized): 0.31243835689283767
# Final epoch: 1000, Final loss (standarized): 0.31165640345068935
# Epoch: 1, Loss (standarized): 0.6936808245558377
# Epoch: 51, Loss (standarized): 0.5145381422958702
# Epoch: 101, Loss (standarized): 0.5131519685401674
# Epoch: 151, Loss (standarized): 0.5101257222029273
# Epoch: 201, Loss (standarized): 0.5112560207782905
# Epoch: 251, Loss (standarized): 0.4688734155916349
# Epoch: 301, Loss (standarized): 0.42339596622424436
# Epoch: 351, Loss (standarized): 0.3905012947837336
# Epoch: 401, Loss (standarized): 0.369494430320585
# Epoch: 451, Loss (standarized): 0.35651661460056666
# Epoch: 501, Loss (standarized): 0.346261076980071
# Epoch: 551, Loss (standarized): 0.33548756271282126
# Epoch: 601, Loss (standarized): 0.329212506943786
# Epoch: 651, Loss (standarized): 0.32268697174862304
# Epoch: 701, Loss (standarized): 0.31862882115026103
# Epoch: 751, Loss (standarized): 0.31615390258246456
# Epoch: 801, Loss (standarized): 0.3136752102761072
# Epoch: 851, Loss (standarized): 0.30754957565712193
# Epoch: 901, Loss (standarized): 0.3078038042296463
# Epoch: 951, Loss (standarized): 0.30462582582932546
# Final epoch: 1000, Final loss (standarized): 0.3058780302867889
# Epoch: 1, Loss (standarized): 0.9689169578602556
# Epoch: 51, Loss (standarized): 0.3153026668568745
# Epoch: 101, Loss (standarized): 0.22091193635188527
# Epoch: 151, Loss (standarized): 0.08681247145639795
# Epoch: 201, Loss (standarized): 0.08124186935597472
# Epoch: 251, Loss (standarized): 0.07630725514158308
# Epoch: 301, Loss (standarized): 0.03831589903728497
# Epoch: 351, Loss (standarized): 0.027841592669731054
# Epoch: 401, Loss (standarized): 0.021879223920844366
# Epoch: 451, Loss (standarized): 0.01900664194004036
# Epoch: 501, Loss (standarized): 0.01676104173833894
# Epoch: 551, Loss (standarized): 0.015580384181205758
# Epoch: 601, Loss (standarized): 0.014943545471178734
# Epoch: 651, Loss (standarized): 0.014657563749068214
# Epoch: 701, Loss (standarized): 0.013952752625850665
# Epoch: 751, Loss (standarized): 0.013727718347266257
# Epoch: 801, Loss (standarized): 0.013246795575466055
# Epoch: 851, Loss (standarized): 0.012847320265158058
# Epoch: 901, Loss (standarized): 0.012480730549103267
# Epoch: 951, Loss (standarized): 0.01221799217933441
# Final epoch: 1000, Final loss (standarized): 0.012162279523140567
# Epoch: 1, Loss (standarized): 0.8331080243851299
# Epoch: 51, Loss (standarized): 0.15808420711335328
# Epoch: 101, Loss (standarized): 0.028389064959389095
# Epoch: 151, Loss (standarized): 0.02127221125148803
# Epoch: 201, Loss (standarized): 0.017773276408899984
# Epoch: 251, Loss (standarized): 0.01675237628941304
# Epoch: 301, Loss (standarized): 0.015926617230195284
# Epoch: 351, Loss (standarized): 0.015580822879119185
# Epoch: 401, Loss (standarized): 0.01616591992742831
# Epoch: 451, Loss (standarized): 0.014982337353160596
# Epoch: 501, Loss (standarized): 0.014743940356702184
# Epoch: 551, Loss (standarized): 0.014456799860582053
# Epoch: 601, Loss (standarized): 0.01431434062770028
# Epoch: 651, Loss (standarized): 0.014021133888703819
# Epoch: 701, Loss (standarized): 0.013458853965195725
# Epoch: 751, Loss (standarized): 0.013180454225704453
# Epoch: 801, Loss (standarized): 0.013381507477042278
# Epoch: 851, Loss (standarized): 0.012913692428652618
# Epoch: 901, Loss (standarized): 0.01278969590201735
# Epoch: 951, Loss (standarized): 0.012392848198278194
# Final epoch: 1000, Final loss (standarized): 0.011925283083544676
# Epoch: 1, Loss (standarized): 0.9427941276519081
# Epoch: 51, Loss (standarized): 0.08913854906135692
# Epoch: 101, Loss (standarized): 0.08491034324245929
# Epoch: 151, Loss (standarized): 0.0850710125933742
# Epoch: 201, Loss (standarized): 0.08472159884666354
# Epoch: 251, Loss (standarized): 0.08489430995188221
# Epoch: 301, Loss (standarized): 0.08527351666372393
# Epoch: 351, Loss (standarized): 0.0848917608949353
# Epoch: 401, Loss (standarized): 0.08452338995510242
# Epoch: 451, Loss (standarized): 0.08471352433502306
# Epoch: 501, Loss (standarized): 0.08618771887720302
# Epoch: 551, Loss (standarized): 0.08485422816023272
# Epoch: 601, Loss (standarized): 0.08458651717739403
# Epoch: 651, Loss (standarized): 0.08530006910178352
# Epoch: 701, Loss (standarized): 0.08534279108479974
# Epoch: 751, Loss (standarized): 0.08473767149629999
# Epoch: 801, Loss (standarized): 0.08532336540170515
# Epoch: 851, Loss (standarized): 0.08490377560787803
# Epoch: 901, Loss (standarized): 0.08475637713173254
# Epoch: 951, Loss (standarized): 0.08477034900184671
# Final epoch: 1000, Final loss (standarized): 0.08468148335956792
# Epoch: 1, Loss (standarized): 0.7073706396403567
# Epoch: 51, Loss (standarized): 0.4150163278412108
# Epoch: 101, Loss (standarized): 0.4141705199294325
# Epoch: 151, Loss (standarized): 0.41145573364545207
# Epoch: 201, Loss (standarized): 0.13201695075953201
# Epoch: 251, Loss (standarized): 0.07953135297526798
# Epoch: 301, Loss (standarized): 0.059393455796852
# Epoch: 351, Loss (standarized): 0.05305380606812356
# Epoch: 401, Loss (standarized): 0.05230960023956595
# Epoch: 451, Loss (standarized): 0.05188547461214636
# Epoch: 501, Loss (standarized): 0.052216466421897534
# Epoch: 551, Loss (standarized): 0.04982703962364206
# Epoch: 601, Loss (standarized): 0.05104835963464503
# Epoch: 651, Loss (standarized): 0.04977821026465258
# Epoch: 701, Loss (standarized): 0.04715609738479491
# Epoch: 751, Loss (standarized): 0.048336270805584565
# Epoch: 801, Loss (standarized): 0.047406679699319165
# Epoch: 851, Loss (standarized): 0.045807734075957424
# Epoch: 901, Loss (standarized): 0.045910553913405386
# Epoch: 951, Loss (standarized): 0.048493846743804164
# Final epoch: 1000, Final loss (standarized): 0.04696361888918241
# Epoch: 1, Loss (standarized): 0.9987045099251718
# Epoch: 51, Loss (standarized): 0.2949091863816917
# Epoch: 101, Loss (standarized): 0.2674465272332352
# Epoch: 151, Loss (standarized): 0.2535838515691008
# Epoch: 201, Loss (standarized): 0.2517017330420056
# Epoch: 251, Loss (standarized): 0.2502334903467967
# Epoch: 301, Loss (standarized): 0.249565849277915
# Epoch: 351, Loss (standarized): 0.2494161764177644
# Epoch: 401, Loss (standarized): 0.2491948607941438
# Epoch: 451, Loss (standarized): 0.24980494439404474
# Epoch: 501, Loss (standarized): 0.24934327727634367
# Epoch: 551, Loss (standarized): 0.24961563102233003
# Epoch: 601, Loss (standarized): 0.2491198547410176
# Epoch: 651, Loss (standarized): 0.24988219356244645
# Epoch: 701, Loss (standarized): 0.24927212660867268
# Epoch: 751, Loss (standarized): 0.24936268265796285
# Epoch: 801, Loss (standarized): 0.24932435623229998
# Epoch: 851, Loss (standarized): 0.24905886762162596
# Epoch: 901, Loss (standarized): 0.24922644731197857
# Epoch: 951, Loss (standarized): 0.24912670563686654
# Final epoch: 1000, Final loss (standarized): 0.2498116389610734
# Epoch: 1, Loss (standarized): 0.7336979652697917
# Epoch: 51, Loss (standarized): 0.05554179129035226
# Epoch: 101, Loss (standarized): 0.02206135994339118
# Epoch: 151, Loss (standarized): 0.0204159514514703
# Epoch: 201, Loss (standarized): 0.020020459842523597
# Epoch: 251, Loss (standarized): 0.0187200061543021
# Epoch: 301, Loss (standarized): 0.01832019780888795
# Epoch: 351, Loss (standarized): 0.0181643400662694
# Epoch: 401, Loss (standarized): 0.017625698825577556
# Epoch: 451, Loss (standarized): 0.017423411747061787
# Epoch: 501, Loss (standarized): 0.017500536982828364
# Epoch: 551, Loss (standarized): 0.01729339601583737
# Epoch: 601, Loss (standarized): 0.017692111223250536
# Epoch: 651, Loss (standarized): 0.016813578619549806
# Epoch: 701, Loss (standarized): 0.015715240352198602
# Epoch: 751, Loss (standarized): 0.015796830497789453
# Epoch: 801, Loss (standarized): 0.015231110039327807
# Epoch: 851, Loss (standarized): 0.01598592726032174
# Epoch: 901, Loss (standarized): 0.01526722110465413
# Epoch: 951, Loss (standarized): 0.014602324917124515
# Final epoch: 1000, Final loss (standarized): 0.015754004412557775
# Epoch: 1, Loss (standarized): 3.0373071619504284
# Epoch: 51, Loss (standarized): 0.26962415681283847
# Epoch: 101, Loss (standarized): 0.2577797150249507
# Epoch: 151, Loss (standarized): 0.24491775536759136
# Epoch: 201, Loss (standarized): 0.23300726736542426
# Epoch: 251, Loss (standarized): 0.034842114804692
# Epoch: 301, Loss (standarized): 0.02696699648789026
# Epoch: 351, Loss (standarized): 0.026282010034266202
# Epoch: 401, Loss (standarized): 0.024549079619775132
# Epoch: 451, Loss (standarized): 0.024173776188534477
# Epoch: 501, Loss (standarized): 0.02363502782828038
# Epoch: 551, Loss (standarized): 0.022542859444826757
# Epoch: 601, Loss (standarized): 0.025363253891676884
# Epoch: 651, Loss (standarized): 0.022582752215394096
# Epoch: 701, Loss (standarized): 0.02592301647798831
# Epoch: 751, Loss (standarized): 0.022590073354012582
# Epoch: 801, Loss (standarized): 0.025408421780999196
# Epoch: 851, Loss (standarized): 0.024474859711315085
# Epoch: 901, Loss (standarized): 0.02228904632784364
# Epoch: 951, Loss (standarized): 0.020178222933722553
# Final epoch: 1000, Final loss (standarized): 0.018821226559390693
# Epoch: 1, Loss (standarized): 0.9317193203679407
# Epoch: 51, Loss (standarized): 0.0804919244571904
# Epoch: 101, Loss (standarized): 0.03429147300320681
# Epoch: 151, Loss (standarized): 0.020309707532925696
# Epoch: 201, Loss (standarized): 0.020249303400796746
# Epoch: 251, Loss (standarized): 0.01958910627257275
# Epoch: 301, Loss (standarized): 0.019621243176741514
# Epoch: 351, Loss (standarized): 0.01933375828119479
# Epoch: 401, Loss (standarized): 0.020765027190748235
# Epoch: 451, Loss (standarized): 0.019953134694517077
# Epoch: 501, Loss (standarized): 0.01959968443787411
# Epoch: 551, Loss (standarized): 0.019297243868003727
# Epoch: 601, Loss (standarized): 0.019569185678861283
# Epoch: 651, Loss (standarized): 0.019197547758091474
# Epoch: 701, Loss (standarized): 0.01992018524387941
# Epoch: 751, Loss (standarized): 0.019998926482944566
# Epoch: 801, Loss (standarized): 0.019659635644173633
# Epoch: 851, Loss (standarized): 0.01925329195314017
# Epoch: 901, Loss (standarized): 0.01935945698474894
# Epoch: 951, Loss (standarized): 0.020271210163128946
# Final epoch: 1000, Final loss (standarized): 0.01913702015202653
# Epoch: 1, Loss (standarized): 1.0944872496241635
# Epoch: 51, Loss (standarized): 0.081448934755868
# Epoch: 101, Loss (standarized): 0.06809350086145478
# Epoch: 151, Loss (standarized): 0.03706126616064741
# Epoch: 201, Loss (standarized): 0.026856545771588653
# Epoch: 251, Loss (standarized): 0.01697023187663181
# Epoch: 301, Loss (standarized): 0.009967557424703144
# Epoch: 351, Loss (standarized): 0.004425826955890121
# Epoch: 401, Loss (standarized): 0.003023301487310449
# Epoch: 451, Loss (standarized): 0.002363561644327573
# Epoch: 501, Loss (standarized): 0.0018910383397803335
# Epoch: 551, Loss (standarized): 0.0016558266611641427
# Epoch: 601, Loss (standarized): 0.0014621057021620802
# Epoch: 651, Loss (standarized): 0.0011967777822571625
# Epoch: 701, Loss (standarized): 0.0011986463463335409
# Epoch: 751, Loss (standarized): 0.0011055648323954404
# Epoch: 801, Loss (standarized): 0.0012345446068249984
# Epoch: 851, Loss (standarized): 0.0011610070657153122
# Epoch: 901, Loss (standarized): 0.0011567018507284569
# Epoch: 951, Loss (standarized): 0.001188900914872414
# Final epoch: 1000, Final loss (standarized): 0.0010914087375482296
# Epoch: 1, Loss (standarized): 0.7812551909677785
# Epoch: 51, Loss (standarized): 0.020107012154602734
# Epoch: 101, Loss (standarized): 0.01248359912399196
# Epoch: 151, Loss (standarized): 0.011810562451353337
# Epoch: 201, Loss (standarized): 0.009180150304533584
# Epoch: 251, Loss (standarized): 0.005354071353213274
# Epoch: 301, Loss (standarized): 0.0037237173752797635
# Epoch: 351, Loss (standarized): 0.001725189634390863
# Epoch: 401, Loss (standarized): 0.0014006196417298757
# Epoch: 451, Loss (standarized): 0.0014846984885109652
# Epoch: 501, Loss (standarized): 0.0014500193067703963
# Epoch: 551, Loss (standarized): 0.0016025902902250453
# Epoch: 601, Loss (standarized): 0.0012666076887863484
# Epoch: 651, Loss (standarized): 0.0012681676518454085
# Epoch: 701, Loss (standarized): 0.0012829585769345555
# Epoch: 751, Loss (standarized): 0.0013029488836625218
# Epoch: 801, Loss (standarized): 0.0011316422217535567
# Epoch: 851, Loss (standarized): 0.0011613082986253252
# Epoch: 901, Loss (standarized): 0.0010352453741126323
# Epoch: 951, Loss (standarized): 0.0011888891954662687
# Final epoch: 1000, Final loss (standarized): 0.0014017016928525115
# Epoch: 1, Loss (standarized): 0.9321167957198089
# Epoch: 51, Loss (standarized): 0.03546028229434921
# Epoch: 101, Loss (standarized): 0.03081129099610585
# Epoch: 151, Loss (standarized): 0.0324560658009575
# Epoch: 201, Loss (standarized): 0.03341671540111367
# Epoch: 251, Loss (standarized): 0.030154122313509092
# Epoch: 301, Loss (standarized): 0.026800535962384575
# Epoch: 351, Loss (standarized): 0.027363812031719604
# Epoch: 401, Loss (standarized): 0.025768922926604366
# Epoch: 451, Loss (standarized): 0.008406259153165882
# Epoch: 501, Loss (standarized): 0.00598154115681856
# Epoch: 551, Loss (standarized): 0.003808291316407017
# Epoch: 601, Loss (standarized): 0.0020290258965242145
# Epoch: 651, Loss (standarized): 0.001887746060632653
# Epoch: 701, Loss (standarized): 0.0019583414709956224
# Epoch: 751, Loss (standarized): 0.0018092686403438306
# Epoch: 801, Loss (standarized): 0.001608822485382632
# Epoch: 851, Loss (standarized): 0.0019939371254302286
# Epoch: 901, Loss (standarized): 0.002346593408261862
# Epoch: 951, Loss (standarized): 0.0020090640077183104
# Final epoch: 1000, Final loss (standarized): 0.0018565584209908558
# Epoch: 1, Loss (standarized): 1.0489307878497698
# Epoch: 51, Loss (standarized): 0.03235355346596513
# Epoch: 101, Loss (standarized): 0.030724037356165974
# Epoch: 151, Loss (standarized): 0.029870201901310584
# Epoch: 201, Loss (standarized): 0.017321141027946248
# Epoch: 251, Loss (standarized): 0.005636036083617998
# Epoch: 301, Loss (standarized): 0.00576679540048588
# Epoch: 351, Loss (standarized): 0.005163203194509778
# Epoch: 401, Loss (standarized): 0.004660962249835648
# Epoch: 451, Loss (standarized): 0.002110008950720618
# Epoch: 501, Loss (standarized): 0.0015977946922386865
# Epoch: 551, Loss (standarized): 0.0017520327191152042
# Epoch: 601, Loss (standarized): 0.00174161461138816
# Epoch: 651, Loss (standarized): 0.0017739004228833708
# Epoch: 701, Loss (standarized): 0.0018973323348525247
# Epoch: 751, Loss (standarized): 0.0015340262957622976
# Epoch: 801, Loss (standarized): 0.0017869346794765599
# Epoch: 851, Loss (standarized): 0.0016981571680798134
# Epoch: 901, Loss (standarized): 0.0014711963096757492
# Epoch: 951, Loss (standarized): 0.0015183900308558982
# Final epoch: 1000, Final loss (standarized): 0.0014869505267264094

# %%
results_df = pd.DataFrame(results).sort_values("Test_loss")
results_df
# Out:
#                Arch                                          Fun    Test_loss  \
# 12   [1, 20, 20, 1]     <function sigmoid at 0x0000028CA7000E00>     3.055278
# 13   [1, 20, 20, 1]        <function tanh at 0x0000028CA7CF32E0>     3.223643
# 15   [1, 20, 20, 1]  <function leaky_relu at 0x0000028CA7CF3600>     3.712780
# 14   [1, 20, 20, 1]        <function relu at 0x0000028CA7CF3420>     7.396732
# 5      [1, 5, 5, 1]        <function tanh at 0x0000028CA7CF32E0>    53.903093
# 4      [1, 5, 5, 1]     <function sigmoid at 0x0000028CA7000E00>    57.417997
# 9   [1, 5, 5, 5, 1]        <function tanh at 0x0000028CA7CF32E0>    68.409202
# 10  [1, 5, 5, 5, 1]        <function relu at 0x0000028CA7CF3420>    79.275383
# 11  [1, 5, 5, 5, 1]  <function leaky_relu at 0x0000028CA7CF3600>    93.502833
# 7      [1, 5, 5, 1]  <function leaky_relu at 0x0000028CA7CF3600>   234.785497
# 1         [1, 5, 1]        <function tanh at 0x0000028CA7CF32E0>   385.819878
# 0         [1, 5, 1]     <function sigmoid at 0x0000028CA7000E00>   427.517375
# 6      [1, 5, 5, 1]        <function relu at 0x0000028CA7CF3420>   473.923893
# 8   [1, 5, 5, 5, 1]     <function sigmoid at 0x0000028CA7000E00>  1432.642625
# 2         [1, 5, 1]        <function relu at 0x0000028CA7CF3420>  1682.510804
# 3         [1, 5, 1]  <function leaky_relu at 0x0000028CA7CF3600>  1685.938096
#
#                                         Train_results
# 12  [1.0944872496241635, 0.9437925398806296, 0.865...
# 13  [0.7812551909677785, 0.5252344718269413, 0.394...
# 15  [1.0489307878497698, 0.5953037536438824, 0.408...
# 14  [0.9321167957198089, 0.5660757957657896, 0.388...
# 5   [0.8331080243851299, 0.7055013667714831, 0.592...
# 4   [0.9689169578602556, 0.89571041166143, 0.80759...
# 9   [0.7336979652697917, 0.5350067150677023, 0.405...
# 10  [3.0373071619504284, 0.9690800033760842, 0.764...
# 11  [0.9317193203679407, 0.5300576895673618, 0.347...
# 7   [0.7073706396403567, 0.6335447916819046, 0.616...
# 1   [1.0173107320917931, 0.7630494563466577, 0.698...
# 0   [1.3933608759143525, 1.1153942386949243, 0.972...
# 6   [0.9427941276519081, 0.7052214385319265, 0.456...
# 8   [0.9987045099251718, 0.987232986324817, 0.9547...
# 2   [0.781493217901631, 0.6448086263771168, 0.5718...
# 3   [0.6936808245558377, 0.5930643768418126, 0.562...

# %% [markdown]
# Widać, że najlepsze aktywacje to sigmoida i tanh, jednak czy nie jest tak dlatego, że ta funkcja jest mocno "ciągła"? Niekoniecznie na przykład na danych steps large będzie tak samo

# %% [markdown]
# ### Wykresy

# %%
titles = ["Sigmoid", "Tanh", "ReLU", "LReLU"]
for i, fun in enumerate(funs):
    for arch in archs:
        y = results_df[pd.concat([results_df["Arch"].apply(lambda x: x==arch), results_df["Fun"].apply(lambda x: x==fun)], axis=1).all(axis=1)].reset_index()["Train_results"][0]
        plt.plot(np.arange(len(y)), y, label = f"Arch: {arch}")
    plt.legend()
    plt.title(f"Loss to epochs for diffrent architectures for {titles[i]}")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.show()

# %% [markdown]
# ## Dane steps-large

# %% [markdown]
# ### Pobranie danych

# %%
# Pobieramy dane
data_train = pd.read_csv("../Data/regression/steps-large-training.csv", index_col=0).to_numpy()
x_train = data_train[:, 0].reshape(-1, 1)
y_train = data_train[:, 1].reshape(-1, 1)

data_test = pd.read_csv("../Data/regression/steps-large-test.csv", index_col=0).to_numpy()
x_test = data_test[:, 0].reshape(-1, 1)
y_test = data_test[:, 1].reshape(-1, 1)

# %%
plt.scatter(x_train, y_train, s = 1, label = "train data")
plt.scatter(x_test, y_test, s = 1, label = "test_data")
plt.legend()
plt.show()

# %% [markdown]
# ### Testy

# %%
np.random.seed(123)
archs = [[1, 20, 20, 1]]
funs = [sigmoid, tanh, relu, leaky_relu]
fun_derivs = [sigmoid_deriv, tanh_deriv, relu_deriv, leaky_relu_deriv]
initialization = ["xavier", "xavier", "he", "he"]
results = { "Arch": [],
            "Fun": [],
            "Test_loss": [],
            "Train_results": []}

for arch in archs:
    for i in range(len(funs)):
        net = MLP(arch, act_fun=funs[i], act_derivative=fun_derivs[i], out_fun=linear, out_derivative=linear_deriv, init_type=initialization[i])
        curr_result = net.train_to_visualize(x = x_train, y = y_train, epochs = 1000, optimizer=Adam(), batch_size=512)
        y_pred = net.predict(x_test)
        test_loss = mse(y_pred, y_test)
        results["Arch"].append(arch)
        results["Fun"].append(funs[i])
        results["Test_loss"].append(test_loss)
        results["Train_results"].append(curr_result)
# Out:
# Epoch: 1, Loss (standarized): 0.6538296342645512
# Epoch: 51, Loss (standarized): 0.07253059184133251
# Epoch: 101, Loss (standarized): 0.07222932564552245
# Epoch: 151, Loss (standarized): 0.06718489462584232
# Epoch: 201, Loss (standarized): 0.020425306716316725
# Epoch: 251, Loss (standarized): 0.012725421151885862
# Epoch: 301, Loss (standarized): 0.00985447281507356
# Epoch: 351, Loss (standarized): 0.007980213800326121
# Epoch: 401, Loss (standarized): 0.006876176152344295
# Epoch: 451, Loss (standarized): 0.006074731233230537
# Epoch: 501, Loss (standarized): 0.00564537390464148
# Epoch: 551, Loss (standarized): 0.0052041408717238115
# Epoch: 601, Loss (standarized): 0.00499164861993716
# Epoch: 651, Loss (standarized): 0.004608948755454213
# Epoch: 701, Loss (standarized): 0.004375103761364673
# Epoch: 751, Loss (standarized): 0.003991164108592393
# Epoch: 801, Loss (standarized): 0.003899653883516758
# Epoch: 851, Loss (standarized): 0.003995221418931374
# Epoch: 901, Loss (standarized): 0.003516772178703543
# Epoch: 951, Loss (standarized): 0.003589999068826121
# Final epoch: 1000, Final loss (standarized): 0.003601936581383852
# Epoch: 1, Loss (standarized): 0.2189399226770111
# Epoch: 51, Loss (standarized): 0.04259905726869727
# Epoch: 101, Loss (standarized): 0.011163758244107166
# Epoch: 151, Loss (standarized): 0.0069823015433401235
# Epoch: 201, Loss (standarized): 0.005220461181600447
# Epoch: 251, Loss (standarized): 0.004721837210586173
# Epoch: 301, Loss (standarized): 0.003785613237600445
# Epoch: 351, Loss (standarized): 0.002878578641166245
# Epoch: 401, Loss (standarized): 0.003429591288521071
# Epoch: 451, Loss (standarized): 0.0023411158714067323
# Epoch: 501, Loss (standarized): 0.0026495756260154044
# Epoch: 551, Loss (standarized): 0.002493379857059979
# Epoch: 601, Loss (standarized): 0.0020684987595553173
# Epoch: 651, Loss (standarized): 0.0023991796606878234
# Epoch: 701, Loss (standarized): 0.001441333975241132
# Epoch: 751, Loss (standarized): 0.0015031765148985072
# Epoch: 801, Loss (standarized): 0.001662250842441536
# Epoch: 851, Loss (standarized): 0.0019293437975822357
# Epoch: 901, Loss (standarized): 0.0014446808449826412
# Epoch: 951, Loss (standarized): 0.0014801689712222296
# Final epoch: 1000, Final loss (standarized): 0.001479635383200237
# Epoch: 1, Loss (standarized): 0.29398663845916806
# Epoch: 51, Loss (standarized): 0.01996596539767701
# Epoch: 101, Loss (standarized): 0.017607174044599903
# Epoch: 151, Loss (standarized): 0.017327417410280342
# Epoch: 201, Loss (standarized): 0.01629103788650097
# Epoch: 251, Loss (standarized): 0.016538048101206217
# Epoch: 301, Loss (standarized): 0.005998842678901982
# Epoch: 351, Loss (standarized): 0.0024103219684486494
# Epoch: 401, Loss (standarized): 0.003596022002829438
# Epoch: 451, Loss (standarized): 0.003107404976818864
# Epoch: 501, Loss (standarized): 0.002599131986219254
# Epoch: 551, Loss (standarized): 0.0037888196190308315
# Epoch: 601, Loss (standarized): 0.0033698616019681056
# Epoch: 651, Loss (standarized): 0.002525055030280588
# Epoch: 701, Loss (standarized): 0.002533582994700219
# Epoch: 751, Loss (standarized): 0.0018621812868913168
# Epoch: 801, Loss (standarized): 0.002023027059352863
# Epoch: 851, Loss (standarized): 0.002259322956332328
# Epoch: 901, Loss (standarized): 0.0030056436505516092
# Epoch: 951, Loss (standarized): 0.003078545950473654
# Final epoch: 1000, Final loss (standarized): 0.0017665295531938134
# Epoch: 1, Loss (standarized): 0.2858107712644713
# Epoch: 51, Loss (standarized): 0.01808103115709157
# Epoch: 101, Loss (standarized): 0.016823387751761166
# Epoch: 151, Loss (standarized): 0.012729064020258968
# Epoch: 201, Loss (standarized): 0.006660917505866441
# Epoch: 251, Loss (standarized): 0.004577155190644455
# Epoch: 301, Loss (standarized): 0.004173392077205106
# Epoch: 351, Loss (standarized): 0.0034112075388902222
# Epoch: 401, Loss (standarized): 0.003171584622294446
# Epoch: 451, Loss (standarized): 0.0045979095737457695
# Epoch: 501, Loss (standarized): 0.0030230138987660223
# Epoch: 551, Loss (standarized): 0.002813449136258805
# Epoch: 601, Loss (standarized): 0.0035608322027492673
# Epoch: 651, Loss (standarized): 0.0030518733698473976
# Epoch: 701, Loss (standarized): 0.003650399628191176
# Epoch: 751, Loss (standarized): 0.002883294656491051
# Epoch: 801, Loss (standarized): 0.0022783547249291035
# Epoch: 851, Loss (standarized): 0.0025103130008973925
# Epoch: 901, Loss (standarized): 0.002128123366173836
# Epoch: 951, Loss (standarized): 0.0025926027972491216
# Final epoch: 1000, Final loss (standarized): 0.0017558406232848164

# %%
results_df = pd.DataFrame(results).sort_values("Test_loss")
results_df
# Out:
#              Arch                                          Fun  Test_loss  \
# 2  [1, 20, 20, 1]        <function relu at 0x0000028CA7CF3420>   6.738343
# 3  [1, 20, 20, 1]  <function leaky_relu at 0x0000028CA7CF3600>   7.794850
# 1  [1, 20, 20, 1]        <function tanh at 0x0000028CA7CF32E0>   8.628865
# 0  [1, 20, 20, 1]     <function sigmoid at 0x0000028CA7000E00>  17.975794
#
#                                        Train_results
# 2  [0.29398663845916806, 0.08252020876914332, 0.0...
# 3  [0.2858107712644713, 0.08684860404950068, 0.06...
# 1  [0.2189399226770111, 0.08448264714194134, 0.07...
# 0  [0.6538296342645512, 0.11083377796919527, 0.07...

# %% [markdown]
# No właśnie i tutaj widać, że relu na tym zbiorze było lepsze

# %%
titles = ["Sigmoid", "Tanh", "ReLU", "LReLU"]
fr = 20
to = 1000
for i, fun in enumerate(funs):
    y = results_df[pd.concat([results_df["Fun"].apply(lambda x: x==fun)], axis=1).all(axis=1)].reset_index()["Train_results"][0]
    plt.plot(np.arange(len(y[fr:to])) + fr, y[fr:to], label = f"Fun: {titles[i]}")
    plt.legend()
plt.title(f"Loss to epochs for diffrent activation functions")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %% [markdown]
# ## Dane rings3-regular

# %% [markdown]
# ### Pobranie

# %%
# Pobieramy dane
data_train = pd.read_csv("../Data/classification/rings3-regular-training.csv").to_numpy()
x_train = data_train[:, 0:2].reshape(-1, 2)
y_train = one_hot(np.int64(data_train[:, 2]))

data_test = pd.read_csv("../Data/classification/rings3-regular-test.csv").to_numpy()
x_test = data_test[:, 0:2].reshape(-1, 2)
y_test = one_hot(np.int64(data_test[:, 2]))

# %%
plt.scatter(x_train[:, 0], x_train[:, 1], c = data_train[:, 2], s = 1)
plt.show()

# %% [markdown]
# ### Testy

# %%
np.random.seed(123)
archs = [[2, 20, 20, 3]]
funs = [sigmoid, tanh, relu, leaky_relu]
fun_derivs = [sigmoid_deriv, tanh_deriv, relu_deriv, leaky_relu_deriv]
initialization = ["xavier", "xavier", "he", "he"]
results = { "Arch": [],
            "Fun": [],
            "Test_loss": [],
            "Fscore": [],
            "Train_results": []}

for arch in archs:
    for i in range(len(funs)):
        net = MLP(arch, act_fun=funs[i], act_derivative=fun_derivs[i], out_fun=softmax, out_derivative=linear_deriv, init_type=initialization[i])
        curr_result = net.train_classify(x = x_train, y = y_train, epochs = 10000, optimizer=Adam(), batch_size=512, loss_fun=cross_entropy)
        y_pred = net.predict(x_test)
        test_loss = cross_entropy(y_pred, y_test)
        y_pred = from_one_hot_to_label(one_hot_from_probabilities(y_pred))
        fscore = f1_score(from_one_hot_to_label(y_test), y_pred)
        results["Arch"].append(arch)
        results["Fun"].append(funs[i])
        results["Test_loss"].append(test_loss)
        results["Train_results"].append(curr_result)
        results["Fscore"].append(fscore)
# Out:
# Epoch: 1, Loss (standarized): 1.1269328409064108
# Epoch: 501, Loss (standarized): 0.15109306404794057
# Epoch: 1001, Loss (standarized): 0.09150054917306538
# Epoch: 1501, Loss (standarized): 0.06070048113273214
# Epoch: 2001, Loss (standarized): 0.041088819614151714
# Epoch: 2501, Loss (standarized): 0.03159192546591342
# Epoch: 3001, Loss (standarized): 0.02450880035926149
# Epoch: 3501, Loss (standarized): 0.020963764553463854
# Epoch: 4001, Loss (standarized): 0.029727439109679153
# Epoch: 4501, Loss (standarized): 0.013453225865714952
# Epoch: 5001, Loss (standarized): 0.011464569496954938
# Epoch: 5501, Loss (standarized): 0.010832551008625705
# Epoch: 6001, Loss (standarized): 0.008510567519668508
# Epoch: 6501, Loss (standarized): 0.00837194616789679
# Epoch: 7001, Loss (standarized): 0.006930516049995672
# Epoch: 7501, Loss (standarized): 0.006845863662857127
# Epoch: 8001, Loss (standarized): 0.005507096642046096
# Epoch: 8501, Loss (standarized): 0.005339473078788754
# Epoch: 9001, Loss (standarized): 0.005152457717931754
# Epoch: 9501, Loss (standarized): 0.004139486359547181
# Final epoch: 10000, Final loss (standarized): 0.00422655191459233
# Epoch: 1, Loss (standarized): 1.188858848133634
# Epoch: 501, Loss (standarized): 0.031984684977950616
# Epoch: 1001, Loss (standarized): 0.01680660618511048
# Epoch: 1501, Loss (standarized): 0.010617956078726455
# Epoch: 2001, Loss (standarized): 0.005634762580901354
# Epoch: 2501, Loss (standarized): 0.004123541873621759
# Epoch: 3001, Loss (standarized): 0.004071674741923094
# Epoch: 3501, Loss (standarized): 0.024173675548701354
# Epoch: 4001, Loss (standarized): 0.0026589255469356646
# Epoch: 4501, Loss (standarized): 0.001450027981067024
# Epoch: 5001, Loss (standarized): 0.0013199703795436807
# Epoch: 5501, Loss (standarized): 0.000960911408514204
# Epoch: 6001, Loss (standarized): 0.09375627857006885
# Epoch: 6501, Loss (standarized): 0.007976788455836487
# Epoch: 7001, Loss (standarized): 0.0007233615352461119
# Epoch: 7501, Loss (standarized): 0.0006435748066815479
# Epoch: 8001, Loss (standarized): 0.000513197746524926
# Epoch: 8501, Loss (standarized): 0.0006068512000929493
# Epoch: 9001, Loss (standarized): 0.00037990326788590396
# Epoch: 9501, Loss (standarized): 0.0003701671587685148
# Final epoch: 10000, Final loss (standarized): 0.00035553457360391595
# Epoch: 1, Loss (standarized): 1.1926070276686096
# Epoch: 501, Loss (standarized): 0.02420949315898316
# Epoch: 1001, Loss (standarized): 0.009577556893527727
# Epoch: 1501, Loss (standarized): 0.006241436279128286
# Epoch: 2001, Loss (standarized): 0.005685669284050814
# Epoch: 2501, Loss (standarized): 0.010629703793257497
# Epoch: 3001, Loss (standarized): 0.002424845522358184
# Epoch: 3501, Loss (standarized): 0.005922561304609195
# Epoch: 4001, Loss (standarized): 0.001983403378765599
# Epoch: 4501, Loss (standarized): 0.0014087853858385712
# Epoch: 5001, Loss (standarized): 0.005621476205811104
# Epoch: 5501, Loss (standarized): 0.0022454328554762735
# Epoch: 6001, Loss (standarized): 0.0011462632904753925
# Epoch: 6501, Loss (standarized): 0.0027237194077134696
# Epoch: 7001, Loss (standarized): 0.0011447140674408368
# Epoch: 7501, Loss (standarized): 0.0009800332029186376
# Epoch: 8001, Loss (standarized): 0.0008961370766922515
# Epoch: 8501, Loss (standarized): 0.000917594425707937
# Epoch: 9001, Loss (standarized): 0.0009472939250128729
# Epoch: 9501, Loss (standarized): 0.0009400356128195349
# Final epoch: 10000, Final loss (standarized): 0.0008599085184534053
# Epoch: 1, Loss (standarized): 2.031938944470957
# Epoch: 501, Loss (standarized): 0.026825164403430832
# Epoch: 1001, Loss (standarized): 0.012990629146043473
# Epoch: 1501, Loss (standarized): 0.007738620409090837
# Epoch: 2001, Loss (standarized): 0.006276976225868365
# Epoch: 2501, Loss (standarized): 0.006931372272402416
# Epoch: 3001, Loss (standarized): 0.004251877759862011
# Epoch: 3501, Loss (standarized): 0.009011981979009704
# Epoch: 4001, Loss (standarized): 0.002955732749537636
# Epoch: 4501, Loss (standarized): 0.003061024294323524
# Epoch: 5001, Loss (standarized): 0.002080892062520217
# Epoch: 5501, Loss (standarized): 0.0032070169254350446
# Epoch: 6001, Loss (standarized): 0.0013298203773154428
# Epoch: 6501, Loss (standarized): 0.0016405042368864188
# Epoch: 7001, Loss (standarized): 0.011015815572202825
# Epoch: 7501, Loss (standarized): 0.0030828321453722865
# Epoch: 8001, Loss (standarized): 0.0017696114787764795
# Epoch: 8501, Loss (standarized): 0.0131143956587639
# Epoch: 9001, Loss (standarized): 0.0010974552090221882
# Epoch: 9501, Loss (standarized): 0.002273527768571458
# Final epoch: 10000, Final loss (standarized): 0.002006955807016073

# %%
results_df = pd.DataFrame(results).sort_values("Test_loss")
results_df
# Out:
#              Arch                                          Fun  Test_loss  \
# 0  [2, 20, 20, 3]     <function sigmoid at 0x0000028CA7000E00>   0.591777
# 1  [2, 20, 20, 3]        <function tanh at 0x0000028CA7CF32E0>   0.607732
# 2  [2, 20, 20, 3]        <function relu at 0x0000028CA7CF3420>   0.643971
# 3  [2, 20, 20, 3]  <function leaky_relu at 0x0000028CA7CF3600>   0.841592
#
#      Fscore                                      Train_results
# 0  0.981558  [1.1269328409064108, 1.112529381545075, 1.1001...
# 1  0.979072  [1.188858848133634, 1.0096299883637747, 1.0031...
# 2  0.977705  [1.1926070276686096, 1.0147772224657856, 0.975...
# 3  0.972697  [2.031938944470957, 1.2873215870802397, 1.0115...

# %%
titles = ["Sigmoid", "Tanh", "ReLU", "LReLU"]
fr = 20
to = 10000
for i, fun in enumerate(funs):
    y = results_df[pd.concat([results_df["Fun"].apply(lambda x: x==fun)], axis=1).all(axis=1)].reset_index()["Train_results"][0]
    plt.plot(np.arange(len(y[fr:to])) + fr, y[fr:to], label = f"Fun: {titles[i]}")
    plt.legend()
plt.title(f"Loss to epochs for diffrent activation functions")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %% [markdown]
# ## Dane rings5-regular

# %% [markdown]
# ### Pobranie

# %%
# Pobieramy dane
data_train = pd.read_csv("../Data/classification/rings5-regular-training.csv").to_numpy()
x_train = data_train[:, 0:2].reshape(-1, 2)
y_train = one_hot(np.int64(data_train[:, 2]))

data_test = pd.read_csv("../Data/classification/rings5-regular-test.csv").to_numpy()
x_test = data_test[:, 0:2].reshape(-1, 2)
y_test = one_hot(np.int64(data_test[:, 2]))

# %%
plt.scatter(x_train[:, 0], x_train[:, 1], c = data_train[:, 2], s = 1)
plt.show()

# %% [markdown]
# ### Testy

# %%
np.random.seed(123)
archs = [[2, 20, 20, 5]]
funs = [sigmoid, tanh, relu, leaky_relu]
fun_derivs = [sigmoid_deriv, tanh_deriv, relu_deriv, leaky_relu_deriv]
initialization = ["xavier", "xavier", "he", "he"]
results = { "Arch": [],
            "Fun": [],
            "Test_loss": [],
            "Fscore": [],
            "Train_results": []}

for arch in archs:
    for i in range(len(funs)):
        net = MLP(arch, act_fun=funs[i], act_derivative=fun_derivs[i], out_fun=softmax, out_derivative=linear_deriv, init_type=initialization[i])
        curr_result = net.train_classify(x = x_train, y = y_train, epochs = 10000, optimizer=Adam(), batch_size=512, loss_fun=cross_entropy)
        y_pred = net.predict(x_test)
        test_loss = cross_entropy(y_pred, y_test)
        y_pred = from_one_hot_to_label(one_hot_from_probabilities(y_pred))
        fscore = f1_score(from_one_hot_to_label(y_test), y_pred)
        results["Arch"].append(arch)
        results["Fun"].append(funs[i])
        results["Test_loss"].append(test_loss)
        results["Train_results"].append(curr_result)
        results["Fscore"].append(fscore)
# Out:
# Epoch: 1, Loss (standarized): 1.6418532995834658
# Epoch: 501, Loss (standarized): 0.12973619778711445
# Epoch: 1001, Loss (standarized): 0.06845784265146475
# Epoch: 1501, Loss (standarized): 0.04147682977480286
# Epoch: 2001, Loss (standarized): 0.02584724946676058
# Epoch: 2501, Loss (standarized): 0.01745867737812253
# Epoch: 3001, Loss (standarized): 0.012323684958723297
# Epoch: 3501, Loss (standarized): 0.008663228288852737
# Epoch: 4001, Loss (standarized): 0.006392179198035028
# Epoch: 4501, Loss (standarized): 0.0058648404322774635
# Epoch: 5001, Loss (standarized): 0.008452472486648988
# Epoch: 5501, Loss (standarized): 0.003284787066955083
# Epoch: 6001, Loss (standarized): 0.0036980424849074774
# Epoch: 6501, Loss (standarized): 0.0021420093222638786
# Epoch: 7001, Loss (standarized): 0.002240360092376841
# Epoch: 7501, Loss (standarized): 0.0017552594028418984
# Epoch: 8001, Loss (standarized): 0.0015430610524984712
# Epoch: 8501, Loss (standarized): 0.0013370803829475739
# Epoch: 9001, Loss (standarized): 0.0012380535638215455
# Epoch: 9501, Loss (standarized): 0.0010224160812885054
# Final epoch: 10000, Final loss (standarized): 0.005529865602338799
# Epoch: 1, Loss (standarized): 1.5334645013465575
# Epoch: 501, Loss (standarized): 0.052962976312808406
# Epoch: 1001, Loss (standarized): 0.02572790254315596
# Epoch: 1501, Loss (standarized): 0.015372949128553567
# Epoch: 2001, Loss (standarized): 0.009116614309658098
# Epoch: 2501, Loss (standarized): 0.016168446587436373
# Epoch: 3001, Loss (standarized): 0.016327282926069563
# Epoch: 3501, Loss (standarized): 0.09704883201134729
# Epoch: 4001, Loss (standarized): 0.017761431301925923
# Epoch: 4501, Loss (standarized): 0.0030822492078060666
# Epoch: 5001, Loss (standarized): 0.018315556166694096
# Epoch: 5501, Loss (standarized): 0.0022617480157949917
# Epoch: 6001, Loss (standarized): 0.008909603518978968
# Epoch: 6501, Loss (standarized): 0.0017762381859745737
# Epoch: 7001, Loss (standarized): 0.0016844750134088428
# Epoch: 7501, Loss (standarized): 0.002261294425999928
# Epoch: 8001, Loss (standarized): 0.001170988572698069
# Epoch: 8501, Loss (standarized): 0.012664732517160972
# Epoch: 9001, Loss (standarized): 0.004701335460413171
# Epoch: 9501, Loss (standarized): 0.0016667962878414945
# Final epoch: 10000, Final loss (standarized): 0.0015372930829089836
# Epoch: 1, Loss (standarized): 1.6774695007509852
# Epoch: 501, Loss (standarized): 0.05266158529513646
# Epoch: 1001, Loss (standarized): 0.02997450195788867
# Epoch: 1501, Loss (standarized): 0.026485516783476683
# Epoch: 2001, Loss (standarized): 0.020544172555421816
# Epoch: 2501, Loss (standarized): 0.01631852207050007
# Epoch: 3001, Loss (standarized): 0.010136681199489335
# Epoch: 3501, Loss (standarized): 0.012952980898413957
# Epoch: 4001, Loss (standarized): 0.011243546832504144
# Epoch: 4501, Loss (standarized): 0.007369919779315015
# Epoch: 5001, Loss (standarized): 0.007596211837561095
# Epoch: 5501, Loss (standarized): 0.006088799595172507
# Epoch: 6001, Loss (standarized): 0.007440306028439865
# Epoch: 6501, Loss (standarized): 0.005281304321999498
# Epoch: 7001, Loss (standarized): 0.010277244518262599
# Epoch: 7501, Loss (standarized): 0.0034300953808197505
# Epoch: 8001, Loss (standarized): 0.005573772793902348
# Epoch: 8501, Loss (standarized): 0.015546270267733711
# Epoch: 9001, Loss (standarized): 0.005356120942433023
# Epoch: 9501, Loss (standarized): 0.003009268719669828
# Final epoch: 10000, Final loss (standarized): 0.0042614418553193634
# Epoch: 1, Loss (standarized): 2.0749095336604397
# Epoch: 501, Loss (standarized): 0.06408385632527741
# Epoch: 1001, Loss (standarized): 0.03450426724197289
# Epoch: 1501, Loss (standarized): 0.029338310414943336
# Epoch: 2001, Loss (standarized): 0.03643078505873431
# Epoch: 2501, Loss (standarized): 0.01086315441005777
# Epoch: 3001, Loss (standarized): 0.014489844873243772
# Epoch: 3501, Loss (standarized): 0.06152690753788981
# Epoch: 4001, Loss (standarized): 0.011977472870857422
# Epoch: 4501, Loss (standarized): 0.005756664564250964
# Epoch: 5001, Loss (standarized): 0.016576719716376195
# Epoch: 5501, Loss (standarized): 0.011011952805428693
# Epoch: 6001, Loss (standarized): 0.0037812442865297964
# Epoch: 6501, Loss (standarized): 0.022978993270071846
# Epoch: 7001, Loss (standarized): 0.009490146262730956
# Epoch: 7501, Loss (standarized): 0.005202886779668101
# Epoch: 8001, Loss (standarized): 0.0026589819755924917
# Epoch: 8501, Loss (standarized): 0.005345070098806855
# Epoch: 9001, Loss (standarized): 0.0063598501635920264
# Epoch: 9501, Loss (standarized): 0.002775049907548206
# Final epoch: 10000, Final loss (standarized): 0.00455939231996265

# %%
results_df = pd.DataFrame(results).sort_values("Test_loss")
results_df
# Out:
#              Arch                                          Fun  Test_loss  \
# 0  [2, 20, 20, 5]     <function sigmoid at 0x0000028CA7000E00>   0.919732
# 1  [2, 20, 20, 5]        <function tanh at 0x0000028CA7CF32E0>   1.213590
# 2  [2, 20, 20, 5]        <function relu at 0x0000028CA7CF3420>   1.318010
# 3  [2, 20, 20, 5]  <function leaky_relu at 0x0000028CA7CF3600>   1.533099
#
#      Fscore                                      Train_results
# 0  0.970043  [1.6418532995834658, 1.6146996352344096, 1.601...
# 1  0.964636  [1.5334645013465575, 1.4192830418485682, 1.372...
# 2  0.957355  [1.6774695007509852, 1.423391283615277, 1.3547...
# 3  0.952728  [2.0749095336604397, 1.5313166767350284, 1.370...

# %%
titles = ["Sigmoid", "Tanh", "ReLU", "LReLU"]
fr = 20
to = 10000
for i, fun in enumerate(funs):
    y = results_df[pd.concat([results_df["Fun"].apply(lambda x: x==fun)], axis=1).all(axis=1)].reset_index()["Train_results"][0]
    plt.plot(np.arange(len(y[fr:to])) + fr, y[fr:to], label = f"Fun: {titles[i]}")
    plt.legend()
plt.title(f"Loss to epochs for diffrent activation functions")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()
